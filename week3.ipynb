# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <center>
#
# # NOTEBOOK TITLE
#
# </center>

# %% [markdown]
# Introducing ourselves. It really isn't hard to work on Markdown. Nor on Python. Nor on anything you set up yourself to do, really.

# %% [markdown]
# Data Science languages:
# - Python
# - R
# - SQL
# - Ruby

# %% [markdown]
# Data Science libraries:
# - PyTorch
# - TensorFlow
# - Keras
# - SciPy
# - NumPy
# - Pandas

# %% [markdown]
# Data Science tools:
#
# | Name | Language (main) | Recommended? |
# | --- | --- | --- |
# | Jupyter Notebook | Python | There's JupyterLab |
# | JupyterLab | Python | Yes, a lot |
# | RStudio | R | If you want to go with R |
# | Spyder | Python | Maybe |

# %% [markdown]
# Let's put some "arithmetic expression" in there
#
# ```python
#
# 256**3
#
# (3+5+7)
#
# 26/7
#
# ```

# %%
(3*4)+5
# Executing this cell will compute the operation
# Out:
# 17

# %%
# Minutes into hours. Straightforward enough (divide by 60)
# In this case let's start with 200 minutes

200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# Not bad
# ![image.png](attachment:31724738-7c8e-45d3-baf8-3eeaa06f1fde.png)
#
# By the way, let's list the objectives (some of them)
#
# - Create a markdown cell to list data science languages.
# - Create a markdown cell to list data science libraries.
# - Create a markdown cell with a table of Data Science tools.

# %% [markdown]
# #### This notebook's author is **Pedro-José Egea-Peláez**. At your service.
#
# (The annexed exercise provided has Lakshmi Holla and Niveditha Pandith as authors.)

# %% [markdown]
# This is how it looks
# ![image.png](attachment:35346978-af1d-48a6-bb9a-1ab4110a649e.png)
